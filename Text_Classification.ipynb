# %% [markdown]
# <a href="https://colab.research.google.com/github/fitrianrr/magang/blob/main/Text_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Library**

# %%
import pandas as pd
import re
import string
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# # **Import Dataset**

# %%
data = pd.read_excel('code dataset.xlsx')
data.head()
# Out:
#                                              subject  \
# 0           Build Platform Otomasi Testing Respon AI
# 1                           ML Playground - Prediksi
# 2  Tambahan Penetapan Mahasiswa Gel 1 2024 11 Jan...
# 3  Tambahan Plotting Penetapan Mahasiswa PPG Praj...
# 4  Proses Migrasi Data email Belajar.id Mahasiswa...
#
#                                           kodefikasi
# 0                    pembuatan tools internal divisi
# 1                    pembuatan tools internal divisi
# 2                      pembuatan bi / dashboard baru
# 3                      pembuatan bi / dashboard baru
# 4  migrasi data jika terkait dengan pengembangan ...

# %% [markdown]
# # **Hapus Missing Value**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 388 entries, 0 to 387
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   subject     388 non-null    object
#  1   kodefikasi  313 non-null    object
# dtypes: object(2)
# memory usage: 6.2+ KB

# %%
data.isnull().sum()
# Out:
# subject        0
# kodefikasi    75
# dtype: int64

# %%
df = data.dropna(axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 313 entries, 0 to 386
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   subject     313 non-null    object
#  1   kodefikasi  313 non-null    object
# dtypes: object(2)
# memory usage: 7.3+ KB

# %% [markdown]
# # **Remove Stop Words**

# %%
docs = df['subject']

# %%
def rem_stopw(text) :
  listStopword =  set(stopwords.words('indonesian'))
  cleaned = []
  for word in text :
    if word not in listStopword :
      cleaned.append(word)
  return ' '.join(cleaned)

# %%
def clean(text) :
  # convert text to lowercase
  lower_text = text.lower()
  # remove number
  numb_text = re.sub(r"\d+", ' ', lower_text)
  # remove punctuation (tanda baca)
  punc_text = numb_text.translate(str.maketrans("","",string.punctuation))

  #remove word that have exacltly 1 character
  processed_text = re.sub(r'\b\w{1}\b', ' ', punc_text)

  cleaned_text = re.sub(r'[【\[][^】\]]*[】\]]', ' ', processed_text)
  # remove stopwords
  no_stopw = rem_stopw(cleaned_text.split())
  return no_stopw

docs_cleaned = docs.apply(clean).tolist()
df['cleaned_text'] = docs_cleaned
# Out:
# <ipython-input-8-dc356c86d61d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['cleaned_text'] = docs_cleaned

# %%
df
# Out:
#                                                subject  \
# 0             Build Platform Otomasi Testing Respon AI
# 1                             ML Playground - Prediksi
# 2    Tambahan Penetapan Mahasiswa Gel 1 2024 11 Jan...
# 3    Tambahan Plotting Penetapan Mahasiswa PPG Praj...
# 4    Proses Migrasi Data email Belajar.id Mahasiswa...
# ..                                                 ...
# 382  Proses Migrasi Data Tambahan Detail Course pro...
# 383  Proses Migrasi Data Calon Fasilitator LMS Pemb...
# 384  Proses Migrasi Data Calon Fasilitator LMS Pemb...
# 385  [GP KS PSP] Proses Migrasi data tambahan kandi...
# 386  [Data Dictionary] Setup data dictionary dengan...
#
#                                             kodefikasi  \
# 0                      pembuatan tools internal divisi
# 1                      pembuatan tools internal divisi
# 2                        pembuatan bi / dashboard baru
# 3                        pembuatan bi / dashboard baru
# ...

# %%
import re
import string
from nltk.tokenize import word_tokenize

# Fungsi utama untuk membersihkan teks
def clean_text(text):
    # Hapus karakter khusus, mention, hashtag, dan link
    text = re.sub(r"\\t|\\n|\\u|\\", " ", text)  # Hapus tab, newline, dan backslash
    text = text.encode('ascii', 'replace').decode('ascii')  # Hapus karakter non-ASCII
    text = re.sub(r"([@#][A-Za-z0-9]+)|(\w+:\/\/\S+)", " ", text)  # Hapus mention, hashtag, dan link
    text = text.replace("http://", " ").replace("https://", " ")  # Hapus URL yang tidak lengkap
    text = re.sub(r"\d+", "", text)  # Hapus angka
    text = text.translate(str.maketrans("", "", string.punctuation))  # Hapus tanda baca
    text = re.sub(r"\b[a-zA-Z]\b", "", text)  # Hapus karakter tunggal
    text = re.sub(r"\s+", " ", text).strip()  # Hapus spasi ganda dan spasi di awal/akhir
    return text

# Terapkan pembersihan dan tokenisasi pada kolom 'tweet'
TWEET_DATA['cleaned_tweet'] = TWEET_DATA['tweet'].apply(lambda x: word_tokenize(clean_text(x)))

print('Tokenizing Result:\n')
print(TWEET_DATA['cleaned_tweet'].head())

# %% [markdown]
# # **Tokenisasi**

# %%
from nltk.tokenize import word_tokenize
tokenized_text = df['cleaned_text'].apply(word_tokenize)

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()
stemmed_text = df['cleaned_text'].apply(lambda x: stemmer.stem(x))

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X_bow = vectorizer.fit_transform(docs_cleaned)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(docs_cleaned)

# %%
from gensim.models import Word2Vec
model = Word2Vec(tokenized_text, vector_size=100, window=5, min_count=1, workers=4)
word_vectors = model.wv

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, labels, test_size=0.2)
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5f40c82cc75d> in <cell line: 3>()
#       1 from sklearn.model_selection import train_test_split
#       2 from sklearn.linear_model import LogisticRegression
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X_tfidf, labels, test_size=0.2)
#       4 model = LogisticRegression()
#       5 model.fit(X_train, y_train)
#
# NameError: name 'labels' is not defined

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

# Assuming 'df' is your DataFrame and 'target_column' is the name of the column containing your labels
labels = df['cleaned_text']  # Replace 'target_column' with the actual column name

# Initialize TfidfVectorizer and transform the text data
tfidf = TfidfVectorizer()
X_tfidf = tfidf.fit_transform(docs_cleaned)

# Now you can use 'labels' in train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, labels, test_size=0.2)

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred = model.predict(X_test)
print(f'Accuracy: {accuracy_score(y_test, y_pred)}')
# Out:
# Accuracy: 0.015873015873015872

# %%
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import LSTM, Dense, Embedding

# Assuming tokenized_text has been converted to integer sequences
X_train_pad = pad_sequences(tokenized_text_train, maxlen=100)
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=100, input_length=100))
model.add(LSTM(128))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train_pad, y_train, epochs=5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-09185cb9e43a> in <cell line: 6>()
#       4
#       5 # Assuming tokenized_text has been converted to integer sequences
# ----> 6 X_train_pad = pad_sequences(tokenized_text_train, maxlen=100)
#       7 model = Sequential()
#       8 model.add(Embedding(input_dim=vocab_size, output_dim=100, input_length=100))
#
# NameError: name 'tokenized_text_train' is not defined

# %% [markdown]
# # **LTSM**

# %%
from tqdm import tqdm
preprocessed_title = []
# tqdm is for printing the status bar
for sentance in tqdm(df['cleaned_text'].values):
  sent = decontracted(sentance)
  sent = sent.replace('\\r', ' ')
  sent = sent.replace('\\"', ' ')
  sent = sent.replace('\\n', ' ')
  sent = re.sub('[^A-Za-z0-9]+', ' ', sent)
  # https://gist.github.com/sebleier/554280
  sent = ' '.join(e for e in sent.split() if e not in stopwords)
  preprocessed_title.append(sent.lower().strip())
# Out:
#   0%|          | 0/313 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-9c3924b89b1f> in <cell line: 4>()
#       3 # tqdm is for printing the status bar
#       4 for sentance in tqdm(df['cleaned_text'].values):
# ----> 5   sent = decontracted(sentance)
#       6   sent = sent.replace('\\r', ' ')
#       7   sent = sent.replace('\\"', ' ')
#
# NameError: name 'decontracted' is not defined

# %%
# !pip install contractions

# %%
from tqdm import tqdm
import contractions
import re

# %%
# The maximum number of words to be used. (most frequent)
MAX_NB_WORDS = 50000
# Max number of words in each complaint.
MAX_SEQUENCE_LENGTH = 250
# This is fixed.
EMBEDDING_DIM = 100
tokenizer = Tokenizer(num_words=MAX_NB_WORDS, lower=True)
tokenizer.fit_on_texts(df['cleaned_text'].values)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 532 unique tokens.
